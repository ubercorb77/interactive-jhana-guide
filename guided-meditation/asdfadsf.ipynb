# %%
def hey(text):
    print([c for c in text if c.isalnum() or c.isspace()])
    words = ''.join(c for c in text if c.isalnum() or c.isspace()).split()
    return words

# %%
print(hey("wdofsf"))
print(hey("aaa, aa."))
print()
# Out:
# ['w', 'd', 'o', 'f', 's', 'f']
# ['wdofsf']
# ['a', 'a', 'a', ' ', 'a', 'a']
# ['aaa', 'aa']
